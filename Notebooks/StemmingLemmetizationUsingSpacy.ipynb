# %%
import nltk
import spacy

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
words = [
  'name',
  'Astar',
  'Degen',
  '9695',
  'description',
  'ASTAR',
  'DEGENS',
  'is',
  'a',
  'NFT',
  'based',
  'DAO',
  'that',
  'envisions',
  'to',
  'incubate',
  'promising',
  'projects',
  'and',
  'bring',
  'new',
  'ideas',
  'to',
  'the',
  'Astar',
  'Ecosystem',
  'with',
  'the',
  'help',
  'of',
  'a',
  'community',
  'governed',
  'DAO',
  'fund',
  'image',
  'ipfs',
  'QmSQ2FHMTi8MFa88ERS6niseb2ggeGrBvqsLZHgd23L8sF',
  '9695',
  'png',
  'dna',
  '03bf7bcf7c629a18020bb04d81becb636609c861',
  'edition',
  '392',
  'date',
  '1645205300974',
  'attributes',
  'trait_type',
  'BACKGROUND',
  'value',
  'Grey',
  'Green',
  'trait_type',
  'BACKATTACHMENT',
  'value',
  'Katana',
  'trait_type',
  'BODY',
  'value',
  'Red',
  'trait_type',
  'EYE',
  'value',
  'Sky',
  'Blue',
  'trait_type',
  'ATTIRE',
  'value',
  'Morpheus',
  'trait_type',
  'ACCESSORIES',
  'value',
  'Gangster',
  'Chain',
  'trait_type',
  'EYEGLASSES',
  'value',
  'None',
  'trait_type',
  'HAT',
  'value',
  'Head',
  'Band',
  'trait_type',
  'MOUTH',
  'value',
  'Roar',
  'trait_type',
  'ARMOR',
  'value',
  'Red',
  'Gold',
  'Shield',
  'compiler',
  'HashLips',
  'Art',
  'Engine',
  'Communal',
  'Fire',
  'Firaga'
]

for word in words:
  print(word, "|", stemmer.stem(word))
# Out:
# name | name
# Astar | astar
# Degen | degen
# 9695 | 9695
# description | descript
# ASTAR | astar
# DEGENS | degen
# is | is
# a | a
# NFT | nft
# based | base
# DAO | dao
# that | that
# envisions | envis
# to | to
# incubate | incub
# promising | promis
# projects | project
# and | and
# bring | bring
# new | new
# ideas | idea
# to | to
# the | the
# Astar | astar
# Ecosystem | ecosystem
# with | with
# the | the
# help | help
# of | of
# a | a
# community | commun
# governed | govern
# DAO | dao
# fund | fund
# image | imag
# ipfs | ipf
# QmSQ2FHMTi8MFa88ERS6niseb2ggeGrBvqsLZHgd23L8sF | qmsq2fhmti8mfa88ers6niseb2ggegrbvqslzhgd23l8sf
# 9695 | 9695
# png | png
# dna | dna
# 03bf7bcf7c629a18020bb04d81becb636609c861 | 03bf7bcf7c629a18020bb04d81becb636609c861
# edition | edit
# 392 | 392
# date | date
# 1645205300974 | 1645205300974
# attributes | attribut
# trait_type | trait_typ
# BACKGROUND | background
# value | valu
# Grey | grey
# Green | green
# trait_type | trait_typ
# ...

# %%
nlp = spacy.load("en_core_web_sm")
tokens = nlp("name Astar Degen 9695 description ASTAR DEGENS is a NFT based DAO that envisions to incubate promising projects and bring new ideas to the Astar Ecosystem with the help of a community governed DAO fund image ipfs QmSQ2FHMTi8MFa88ERS6niseb2ggeGrBvqsLZHgd23L8sF 9695 png dna 03bf7bcf7c629a18020bb04d81becb636609c861 edition 392 date 1645205300974 attributes trait_type BACKGROUND value Grey Green trait_type BACKATTACHMENT value Katana trait_type BODY value Red trait_type EYE value Sky Blue trait_type ATTIRE value Morpheus trait_type ACCESSORIES value Gangster Chain trait_type EYEGLASSES value None trait_type HAT value Head Band trait_type MOUTH value Roar trait_type ARMOR value Red Gold Shield compiler HashLips Art Engine Communal Fire")
for token in tokens:
  print(token,"|", token.lemma_)
# Out:
# name | name
# Astar | Astar
# Degen | Degen
# 9695 | 9695
# description | description
# ASTAR | ASTAR
# DEGENS | DEGENS
# is | be
# a | a
# NFT | NFT
# based | base
# DAO | DAO
# that | that
# envisions | envision
# to | to
# incubate | incubate
# promising | promising
# projects | project
# and | and
# bring | bring
# new | new
# ideas | idea
# to | to
# the | the
# Astar | Astar
# Ecosystem | Ecosystem
# with | with
# the | the
# help | help
# of | of
# a | a
# community | community
# governed | govern
# DAO | DAO
# fund | fund
# image | image
# ipfs | ipfs
# QmSQ2FHMTi8MFa88ERS6niseb2ggeGrBvqsLZHgd23L8sF | QmSQ2FHMTi8MFa88ERS6niseb2ggeGrBvqsLZHgd23L8sF
# 9695 | 9695
# png | png
# dna | dna
# 03bf7bcf7c629a18020bb04d81becb636609c861 | 03bf7bcf7c629a18020bb04d81becb636609c861
# edition | edition
# 392 | 392
# date | date
# 1645205300974 | 1645205300974
# attributes | attribute
# trait_type | trait_type
# BACKGROUND | background
# value | value
# Grey | Grey
# Green | Green
# ...
